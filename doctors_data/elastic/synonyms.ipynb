# %%
disease_data = [
    {
        "disease": "Influenza",
        "persian_name": "آنفولانزا",
        "synonyms": ["گریپ", "سرماخوردگی شدید"],
        "expertise": "Internal Medicine (پزشکی داخلی)",
    },
    {
        "disease": "Diabetes",
        "persian_name": "دیابت",
        "synonyms": ["بیماری قند", "قند خون بالا"],
        "expertise": "Endocrinology (غدد درون‌ریز)",
    },
    {
        "disease": "Hypertension",
        "persian_name": "فشار خون بالا",
        "synonyms": ["پرفشاری خون", "فشارخون زیاد"],
        "expertise": "Cardiology (قلب و عروق)",
    },
    {
        "disease": "Tuberculosis",
        "persian_name": "سل",
        "synonyms": ["توبرکلوز"],
        "expertise": "Pulmonology (ریه و دستگاه تنفسی)",
    },
    {
        "disease": "Asthma",
        "persian_name": "آسم",
        "synonyms": ["تنگی نفس", "نفس‌تنگی"],
        "expertise": "Pulmonology (ریه و دستگاه تنفسی)",
    },
    {
        "disease": "Hepatitis",
        "persian_name": "هپاتیت",
        "synonyms": ["یرقان", "زردی"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Heart Attack",
        "persian_name": "حمله قلبی",
        "synonyms": ["سکته قلبی", "انفارکتوس"],
        "expertise": "Cardiology (قلب و عروق)",
    },
    {
        "disease": "Stroke",
        "persian_name": "سکته مغزی",
        "synonyms": ["حمله مغزی", "انفارکتوس مغزی"],
        "expertise": "Neurology (مغز و اعصاب)",
    },
    {
        "disease": "Cancer",
        "persian_name": "سرطان",
        "synonyms": ["تومور", "تومور بدخیم"],
        "expertise": "Oncology (سرطان‌شناسی)",
    },
    {
        "disease": "Arthritis",
        "persian_name": "آرتروز",
        "synonyms": ["التهاب مفاصل", "روماتیسم"],
        "expertise": "Rheumatology (روماتولوژی)",
    },
    {
        "disease": "Migraine",
        "persian_name": "میگرن",
        "synonyms": ["سردرد میگرنی", "سردرد عصبی"],
        "expertise": "Neurology (مغز و اعصاب)",
    },
    {
        "disease": "Pneumonia",
        "persian_name": "ذات‌الریه",
        "synonyms": ["سینه‌پهلو"],
        "expertise": "Pulmonology (ریه و دستگاه تنفسی)",
    },
    {
        "disease": "Epilepsy",
        "persian_name": "صرع",
        "synonyms": ["تشنج", "بیماری تشنج"],
        "expertise": "Neurology (مغز و اعصاب)",
    },
    {
        "disease": "Anemia",
        "persian_name": "کم‌خونی",
        "synonyms": ["آنمی", "کمبود خون"],
        "expertise": "Hematology (خون‌شناسی)",
    },
    {
        "disease": "Cholera",
        "persian_name": "وبا",
        "synonyms": ["بیماری وبا"],
        "expertise": "Infectious Disease (بیماری‌های عفونی)",
    },
    {
        "disease": "Dysentery",
        "persian_name": "اسهال خونی",
        "synonyms": ["دیسانتری", "بیماری اسهال خونی"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Malaria",
        "persian_name": "مالاریا",
        "synonyms": ["تب و لرز", "بیماری مالاریا"],
        "expertise": "Infectious Disease (بیماری‌های عفونی)",
    },
    {
        "disease": "Appendicitis",
        "persian_name": "آپاندیسیت",
        "synonyms": ["التهاب آپاندیس", "درد شکمی"],
        "expertise": "General Surgery (جراحی عمومی)",
    },
    {
        "disease": "Bronchitis",
        "persian_name": "برونشیت",
        "synonyms": ["التهاب نایچه", "عفونت سینه"],
        "expertise": "Pulmonology (ریه و دستگاه تنفسی)",
    },
    {
        "disease": "Depression",
        "persian_name": "افسردگی",
        "synonyms": ["دل‌گرفتگی", "اضطراب شدید"],
        "expertise": "Psychiatry (روانپزشکی)",
    },
    {
        "disease": "Osteoporosis",
        "persian_name": "پوکی استخوان",
        "synonyms": ["ضعف استخوان", "نرمی استخوان"],
        "expertise": "Endocrinology (غدد درون‌ریز)",
    },
    {
        "disease": "Multiple Sclerosis (MS)",
        "persian_name": "مولتیپل اسکلروزیس",
        "synonyms": ["ام اس", "التهاب اعصاب"],
        "expertise": "Neurology (مغز و اعصاب)",
    },
    {
        "disease": "Parkinson's Disease",
        "persian_name": "بیماری پارکینسون",
        "synonyms": ["لرزش پارکینسون", "اختلال حرکتی"],
        "expertise": "Neurology (مغز و اعصاب)",
    },
    {
        "disease": "Alzheimer's Disease",
        "persian_name": "بیماری آلزایمر",
        "synonyms": ["فراموشی", "اختلال حافظه"],
        "expertise": "Neurology (مغز و اعصاب)",
    },
    {
        "disease": "Gastroesophageal Reflux Disease (GERD)",
        "persian_name": "رفلاکس معده",
        "synonyms": ["بازگشت اسید معده", "ترش کردن"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Irritable Bowel Syndrome (IBS)",
        "persian_name": "سندرم روده تحریک‌پذیر",
        "synonyms": ["روده تحریک‌پذیر", "بیماری آی‌بی‌اس"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Celiac Disease",
        "persian_name": "بیماری سلیاک",
        "synonyms": ["حساسیت به گلوتن", "اختلال گوارشی"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Psoriasis",
        "persian_name": "پسوریازیس",
        "synonyms": ["بیماری پوستی", "التهاب پوستی"],
        "expertise": "Dermatology (پوست)",
    },
    {
        "disease": "Eczema",
        "persian_name": "اگزما",
        "synonyms": ["درماتیت", "التهاب پوستی"],
        "expertise": "Dermatology (پوست)",
    },
    {
        "disease": "Ulcerative Colitis",
        "persian_name": "کولیت اولسراتیو",
        "synonyms": ["التهاب روده", "زخم روده"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Crohn's Disease",
        "persian_name": "بیماری کرون",
        "synonyms": ["التهاب روده", "بیماری التهابی روده"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Chronic Obstructive Pulmonary Disease (COPD)",
        "persian_name": "بیماری انسدادی مزمن ریه",
        "synonyms": ["سی‌او‌پی‌دی", "انسداد ریه"],
        "expertise": "Pulmonology (ریه و دستگاه تنفسی)",
    },
    {
        "disease": "Kidney Stones",
        "persian_name": "سنگ کلیه",
        "synonyms": ["سنگ ادراری", "نفروتیازیس"],
        "expertise": "Urology (ارولوژی)",
    },
    {
        "disease": "Gallstones",
        "persian_name": "سنگ کیسه صفرا",
        "synonyms": ["کلسیفیکاسیون صفرا", "سنگ صفرا"],
        "expertise": "Gastroenterology (گوارش)",
    },
    {
        "disease": "Gout",
        "persian_name": "نقرس",
        "synonyms": ["آرتریت نقرسی", "التهاب مفاصل نقرسی"],
        "expertise": "Rheumatology (روماتولوژی)",
    },
    {
        "disease": "Lupus",
        "persian_name": "لوپوس",
        "synonyms": ["بیماری خودایمنی", "التهاب سیستمیک"],
        "expertise": "Rheumatology (روماتولوژی)",
    },
    {
        "disease": "Thyroiditis",
        "persian_name": "تیروئیدیت",
        "synonyms": ["التهاب تیروئید", "بیماری تیروئید"],
        "expertise": "Endocrinology (غدد درون‌ریز)",
    },
    {
        "disease": "Hyperthyroidism",
        "persian_name": "پرکاری تیروئید",
        "synonyms": ["تیروئید پرکار", "افزایش هورمون تیروئید"],
        "expertise": "Endocrinology (غدد درون‌ریز)",
    },
    {
        "disease": "Hypothyroidism",
        "persian_name": "کم‌کاری تیروئید",
        "synonyms": ["تیروئید کم‌کار", "کاهش هورمون تیروئید"],
        "expertise": "Endocrinology (غدد درون‌ریز)",
    },
]

# %%
# List to hold all the formatted synonym entries
synonyms_list = []

# Iterate over each disease entry
for entry in disease_data:
    persian_name = entry["persian_name"]
    synonyms = entry["synonyms"]

    # Create a string for each synonym group including the Persian name
    synonyms_entry = f"{persian_name}, " + ", ".join(synonyms)
    synonyms_list.append(synonyms_entry)

# Join all synonym entries into a single string with newlines
synonyms_string = "\n".join(synonyms_list)

# Save to a synonyms.txt file
with open("synonyms.txt", "w", encoding="utf-8") as file:
    file.write(synonyms_string)

print("Synonyms file created successfully.")
# Out:
# Synonyms file created successfully.

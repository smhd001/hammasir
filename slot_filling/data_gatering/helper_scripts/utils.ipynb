# %%
def get_tags():
    tagss_name = [  # noqa: F841
    "problem",
    "city",
    "expertise",
    "gender",
    "neighborhood",
    "online-or-inperson",
    "insuracen",
    "first-available-appointment",
    "amount-of-delay",
    "moral",
    "user-score",
    ]
    seletced_tags_name = [
    "problem",
    "city",
    "expertise",
    "gender",
    ]   
    NOLABLE = "O"
    tags_list = []
    for name in seletced_tags_name:
        tags_list.extend([f"B-{name}", f"I-{name}"])
    tags_list.append(NOLABLE)
    return tags_list

get_tags()

# %%
def tsv_to_dict(text):
    pass
def conll_to_tsv(text):
    pass
def tsv_to_conll(text):
    pass
